# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import MaxNLocator
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import plotly.io as pio
import pandas as pd

# %%
# printing 
import numpy as np
from matplotlib.ticker import MaxNLocator
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import matplotlib

font = {'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
inputFileName = "/Users/mxm/Google Drive/Masterstudium/Inhalte/Master Thesis/GitHubRepo/agile-in-government/Analysis/2_Data_Preprocessing/DATA/CSVs/UK/General_v1.csv"
df=pd.read_csv(inputFileName, parse_dates=["final_date"])
plot=df[df.final_date < '2019-12-31 23:59:59']["final_date"].groupby([df["final_date"].dt.year]).count().plot(kind="bar", figsize=(20,10))
plot.set_xlabel("Years")
plot.set_ylabel("Websites published with the term agil / agility")
plot.set_title("gov.uk")
plot

# %%
df.final_date.describe()
# Out:
# count                     833
# unique                    747
# top       2017-02-17 09:07:05
# freq                       21
# first     2004-01-01 00:00:00
# last      2020-02-07 17:25:56
# Name: final_date, dtype: object

# %%
InputFileName = "/Users/mxm/Google Drive/Masterstudium/Inhalte/Master Thesis/GitHubRepo/agile-in-government/Analysis/2_Data_Preprocessing/DATA/CSVs/UK/General_v1.csv"

df=pd.read_csv(inputFileName, parse_dates=["final_date"])
fig,ax1 = plt.subplots()
plt.plot(df[df.final_date < '2019-12-31 23:59:59']["final_date"].groupby([df["final_date"].dt.year]).count().plot(kind="bar"))
monthyearFmt = mdates.DateFormatter('%Y')
ax1.xaxis.set_major_formatter(monthyearFmt)
_ = plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-702ef3b38ab7> in <module>
#       3 df=pd.read_csv(inputFileName, parse_dates=["final_date"])
#       4 fig,ax1 = plt.subplots()
# ----> 5 plt.plot(df[df.final_date < '2019-12-31 23:59:59']["final_date"].groupby([df["final_date"].dt.year]).count().plot(kind="bar"))
#       6 monthyearFmt = mdates.DateFormatter('%Y')
#       7 ax1.xaxis.set_major_formatter(monthyearFmt)
#
# /anaconda3/envs/Scraper_v1/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# /anaconda3/envs/Scraper_v1/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
data = [dict(
  x = df['final_date'],
  autobinx = True,
  autobiny = False,
  marker = dict(color = 'rgb(0,0,128)'),
  name = 'date',
  type = 'histogram',
  xbins = dict(
    end = '2019-12-31 23:59',
    size = 'M1',
    start = '2004-01-01 00:00'
  )
)]

layout = dict(
  paper_bgcolor = 'rgb(255,255,255)',
  plot_bgcolor = 'rgb(211,211,211)',
  title = '<b>gov.uk</b>',
  xaxis = dict(
    title = 'Years',
    type = 'date'
  ),
  yaxis = dict(
    title = 'Websites published with the term agil / agility"',
    type = 'linear'
  ),
  updatemenus = [dict(
        x = 0.1,
        y = 1.15,
        xref = 'paper',
        yref = 'paper',
        yanchor = 'top',
        active = 1,
        showactive = True,
        buttons = [
        dict(
            args = ['xbins.size', 'D1'],
            label = 'Day',
            method = 'restyle',
        ), dict(
            args = ['xbins.size', 'M1'],
            label = 'Month',
            method = 'restyle',
        ), dict(
            args = ['xbins.size', 'M3'],
            label = 'Quater',
            method = 'restyle',
        ), dict(
            args = ['xbins.size', 'M6'],
            label = 'Half Year',
            method = 'restyle',
        ), dict(
            args = ['xbins.size', 'M12'],
            label = 'Year',
            method = 'restyle',
        )]
  )]
)

fig_dict = dict(data=data, layout=layout)

pio.show(fig_dict, validate=False)

# %%
import plotly.express as px
data_canada = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(data_canada, x='year', y='pop')
fig.show()

# %%
fig = px.bar(df, x="final_date", y="total_bill", color="smoker", barmode="group",
             facet_row="time", facet_col="day",
             category_orders={"day": ["Thur", "Fri", "Sat", "Sun"],
                              "time": ["Lunch", "Dinner"]})
fig.show()

# %%
import pandas as pd
from numpy.random import randint
import matplotlib.pyplot as plt
InputFileName = "/Users/mxm/Google Drive/Masterstudium/Inhalte/Master Thesis/GitHubRepo/agile-in-government/Analysis/2_Data_Preprocessing/DATA/CSVs/UK/General_v1.csv"

df=pd.read_csv(inputFileName, parse_dates=["final_date"])
grouped = df[df.final_date < '2019-12-31 23:59:59']["final_date"].groupby([df["final_date"].dt.year]).count()
#grouped = df.groupby([final_date)
rowlength = grouped.ngroups/2                         # fix up if odd number of groups
fig, axs = plt.subplots(figsize=(9,4), 
                        nrows=2, ncols=rowlength,     # fix as above
                        gridspec_kw=dict(hspace=0.4)) # Much control of gridspec

targets = zip(grouped.groups.keys(), axs.flatten())
for i, (key, ax) in enumerate(targets):
    ax.plot(grouped.get_group(key))
    ax.set_title('a=%d'%key)
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-f5a4b34fa40c> in <module>
#       7 grouped = df[df.final_date < '2019-12-31 23:59:59']["final_date"].groupby([df["final_date"].dt.year]).count()
#       8 #grouped = df.groupby([final_date)
# ----> 9 rowlength = grouped.ngroups/2                         # fix up if odd number of groups
#      10 fig, axs = plt.subplots(figsize=(9,4),
#      11                         nrows=2, ncols=rowlength,     # fix as above
#
# /anaconda3/envs/Scraper_v1/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# ...

# %%
grouped = df[df.final_date < '2019-12-31 23:59:59']["final_date"].groupby([df["final_date"].dt.year]).count()
